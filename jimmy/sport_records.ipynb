# %%
# 2019_10_12 運動紀錄(night)
jimmy = ['2019-10-12 18:28:00', '2019-10-12 18:32:08', 'fast',
         '2019-10-12 18:32:08', '2019-10-12 18:37:26', 'run',
         '2019-10-12 18:38:55', '2019-10-12 18:44:23', 'slow',
         '2019-10-12 18:44:23', '2019-10-12 18:55:13', 'run',
         '2019-10-12 18:55:13', '2019-10-12 19:00:37', 'slow',]

austin = ['2019-10-12 18:23:24', '2019-10-12 18:28:07', 'fast', 
          '2019-10-12 18:28:07', '2019-10-12 18:40:01', 'run', 
          '2019-10-12 18:40:01', '2019-10-12 18:44:31', 'fast', 
          '2019-10-12 18:44:31', '2019-10-12 18:57:35', 'slow',]

hul = ['2019-10-12 18:25:12', '2019-10-12 18:30:12', 'run',
       '2019-10-12 18:30:12', '2019-10-12 18:35:11', 'fast',
       '2019-10-12 18:35:11', '2019-10-12 18:38:15', 'run',
       '2019-10-12 18:38:15', '2019-10-12 18:44:30', 'slow',
       '2019-10-12 18:44:30', '2019-10-12 18:47:26', 'run',
       '2019-10-12 18:47:26','2019-10-12 18:52:59','fast',
       '2019-10-12 18:52:59','2019-10-12 18:55:51', 'run']

buffet = ['2019-10-12 18:24:11', '2019-10-12 18:28:40', 'fast',
          '2019-10-12 18:28:40', '2019-10-12 18:50:16', 'run',
          '2019-10-12 18:50:16', '2019-10-12 18:57:35', 'slow',]

yoyo = ['2019-10-12 18:27:00', '2019-10-12 18:31:07', 'slow',
        '2019-10-12 18:31:07', '2019-10-12 18:36:36', 'fast',
        '2019-10-12 18:37:16', '2019-10-12 18:45:30', 'run',
        '2019-10-12 18:45:30', '2019-10-12 18:50:03', 'fast',
        '2019-10-12 18:50:03', '2019-10-12 19:03:40', 'run',
        '2019-10-12 19:03:40','2019-10-12 19:08:18', 'slow',]

# %%
# 2019_10_12 運動紀錄(afternoon)
jimmy = ['2019-10-12 12:30:00', '2019-10-12 12:43:50', 'fast',
         '2019-10-12 12:43:50', '2019-10-12 12:52:30', 'slow',]

# %%
# 2019_10_08 運動紀錄
jimmy = ['2019-10-08 18:24:00', '2019-10-08 18:29:00', 'fast',
         '2019-10-08 18:29:00', '2019-10-08 18:32:00', 'run',
         '2019-10-08 18:44:00', '2019-10-08 18:52:00', 'run',
         '2019-10-08 18:52:00', '2019-10-08 18:59:00', 'slow',]

austin = ['2019-10-08 18:24:00', '2019-10-08 18:28:00', 'fast',
          '2019-10-08 18:28:00', '2019-10-08 18:41:00', 'run',
          '2019-10-08 18:41:00', '2019-10-08 18:45:00', 'fast',
          '2019-10-08 18:45:00', '2019-10-08 18:51:00', 'slow',
          '2019-10-08 18:51:00', '2019-10-08 18:57:00', 'run',]

hul = ['2019-10-08 18:22:00', '2019-10-08 18:27:00', 'run',
       '2019-10-08 18:27:00', '2019-10-08 18:33:00', 'fast',
       '2019-10-08 18:33:00', '2019-10-08 18:35:00', 'run',
       '2019-10-08 18:35:00', '2019-10-08 18:42:00', 'slow',
       '2019-10-08 18:42:00', '2019-10-08 18:45:00', 'run',
       '2019-10-08 18:45:00', '2019-10-08 18:50:00', 'fast',]

buffet = ['2019-10-08 18:22:00', '2019-10-08 18:26:00', 'fast',
          '2019-10-08 18:26:00', '2019-10-08 18:43:00', 'run',
          '2019-10-08 18:43:00', '2019-10-08 18:51:00', 'slow',]

yoyo = ['2019-10-08 18:35:00', '2019-10-08 18:40:00', 'slow',
        '2019-10-08 18:40:00', '2019-10-08 18:45:00', 'fast',
        '2019-10-08 18:45:00', '2019-10-08 18:58:00', 'run',
        '2019-10-08 18:58:00', '2019-10-08 19:03:00', 'fast',
        '2019-10-08 19:03:00', '2019-10-08 19:20:00', 'slow',
        '2019-10-08 19:20:00', '2019-10-08 19:24:00', 'fast',]

# %%
# 2019_10_07 運動紀錄
jimmy = ['2019-10-07 18:22:00', '2019-10-07 18:27:00', 'fast',
         '2019-10-07 18:27:00', '2019-10-07 18:35:00', 'run',
         '2019-10-07 18:35:00', '2019-10-07 18:39:00', 'fast',
         '2019-10-07 18:39:00', '2019-10-07 18:44:00', 'run',
         '2019-10-07 18:44:00', '2019-10-07 18:47:00', 'slow',]

austin = ['2019-10-07 18:18:00', '2019-10-07 18:22:00', 'slow',
          '2019-10-07 18:23:00', '2019-10-07 18:36:00', 'run',
          '2019-10-07 18:36:00', '2019-10-07 18:41:00', 'fast',
          '2019-10-07 18:41:00', '2019-10-07 18:47:00', 'slow',]

hul = ['2019-10-07 18:18:00', '2019-10-07 18:24:00', 'run',
       '2019-10-07 18:24:00', '2019-10-07 18:29:00', 'fast',
       '2019-10-07 18:29:00', '2019-10-07 18:32:00', 'run',
       '2019-10-07 18:32:00', '2019-10-07 18:38:00', 'slow',
       '2019-10-07 18:38:00', '2019-10-07 18:41:00', 'run',
       '2019-10-07 18:41:00', '2019-10-07 18:46:00', 'fast',]

buffet = ['2019-10-07 18:31:00', '2019-10-07 18:35:00', 'fast',
          '2019-10-07 18:35:00', '2019-10-07 18:48:00', 'run',
          '2019-10-07 18:48:00', '2019-10-07 18:55:00', 'slow',]

yoyo = ['2019-10-07 18:19:00', '2019-10-07 18:25:00', 'slow',
        '2019-10-07 18:25:00', '2019-10-07 18:29:00', 'fast',
        '2019-10-07 18:29:00', '2019-10-07 18:38:00', 'run',
        '2019-10-07 18:38:00', '2019-10-07 18:43:00', 'fast',
        '2019-10-07 18:43:00', '2019-10-07 19:00:00', 'run',
        '2019-10-07 19:00:00', '2019-10-07 19:04:00', 'fast',
        '2019-10-07 19:04:00', '2019-10-07 19:08:00', 'slow',]

# %%
# 2019_10_05 運動紀錄
jimmy = ['2019-10-05 18:29:00', '2019-10-05 18:38:00', 'fast',
         '2019-10-05 18:38:00', '2019-10-05 18:45:00', 'slow',
         '2019-10-05 18:45:00', '2019-10-05 18:53:00', 'fast',]

austin = ['2019-10-05 18:26:00', '2019-10-05 18:30:00', 'fast',
          '2019-10-05 18:30:00', '2019-10-05 18:46:00', 'run',
          '2019-10-05 18:43:00', '2019-10-05 18:47:00', 'fast',
          '2019-10-05 18:47:00', '2019-10-05 18:53:00', 'slow',]

hul = ['2019-10-05 18:27:00', '2019-10-05 18:32:00', 'run',
       '2019-10-05 18:32:00', '2019-10-05 18:37:00', 'fast',
       '2019-10-05 18:37:00', '2019-10-05 18:40:00', 'run',
       '2019-10-05 18:40:00', '2019-10-05 18:47:00', 'slow',
       '2019-10-05 18:47:00', '2019-10-05 18:50:00', 'run',]

buffet = ['2019-10-05 18:28:00', '2019-10-05 18:32:00', 'fast',
          '2019-10-05 18:32:00', '2019-10-05 18:42:00', 'run',
          '2019-10-05 18:42:00', '2019-10-05 18:50:00', 'slow',
          '2019-10-05 18:50:00', '2019-10-05 18:57:00', 'slow',]

yoyo = ['2019-10-05 18:32:00', '2019-10-05 18:37:00', 'slow',
        '2019-10-05 18:37:00', '2019-10-05 18:41:00', 'fast',
        '2019-10-05 18:41:00', '2019-10-05 18:51:00', 'run',
        '2019-10-05 18:51:00', '2019-10-05 18:55:00', 'slow',
        '2019-10-05 18:55:00', '2019-10-05 19:09:00', 'run',
        '2019-10-05 19:09:00', '2019-10-05 19:14:00', 'slow',
        '2019-10-05 19:14:00', '2019-10-05 19:18:00', 'run',
        '2019-10-05 19:18:00', '2019-10-05 19:22:00', 'fast',]

# %%
# 2019_10_04 運動紀錄(程式碼有異動作廢)
jimmy = ['2019-10-04 19:21:00', '2019-10-04 19:29:00', 'run',
         '2019-10-04 19:31:00', '2019-10-04 19:35:00', 'fast',
         '2019-10-04 19:35:00', '2019-10-04 19:40:00', 'run',
         '2019-10-04 19:40:00', '2019-10-04 19:42:00', 'slow',]

austin = ['2019-10-04 19:19:00', '2019-10-04 19:32:00', 'run',
          '2019-10-04 19:33:00', '2019-10-04 19:36:00', 'fast',
          '2019-10-04 19:36:00', '2019-10-04 19:43:00', 'slow',
          '2019-10-04 19:42:00', '2019-10-04 19:49:00', 'fast',]

hul = ['2019-10-04 19:20:00', '2019-10-04 19:26:00', 'run',
       '2019-10-04 19:26:00', '2019-10-04 19:31:00', 'fast',
       '2019-10-04 19:31:00', '2019-10-04 19:34:00', 'run',
       '2019-10-04 19:34:00', '2019-10-04 19:41:00', 'slow',
       '2019-10-04 19:41:00', '2019-10-04 19:44:00', 'run',]

buffet = ['2019-10-04 19:21:00', '2019-10-04 19:31:00', 'run',
          '2019-10-04 19:31:00', '2019-10-04 19:38:00', 'slow',
          '2019-10-04 19:38:00', '2019-10-04 19:42:00', 'fast',
          '2019-10-04 19:43:00', '2019-10-04 19:49:00', 'slow',]

yoyo = ['2019-10-08 18:35:00', '2019-10-08 18:40:00', 'slow',
        '2019-10-08 18:40:00', '2019-10-08 18:45:00', 'fast',
        '2019-10-08 18:45:00', '2019-10-08 18:58:00', 'run',
        '2019-10-08 18:58:00', '2019-10-08 19:03:00', 'fast',
        '2019-10-08 19:03:00', '2019-10-08 19:20:00', 'slow',
        '2019-10-08 19:20:00', '2019-10-08 19:24:00', 'fast',]
