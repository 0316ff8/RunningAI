# %%
## consume to Elasticsearch
from kafka import KafkaConsumer
import sys, json
# import pymongo
from elasticsearch import Elasticsearch
import time, datetime


if __name__ == "__main__":

    # 與 MongoDB連線
#     client = pymongo.MongoClient(host="mongodb", port=27017)
    # 指定為 test 資料庫
#     db = client.test
    # 指定 temp_humidity 集合, MongoDB的每個資料庫又包含許多集合(collection), 類似於關聯性資料庫中的表
#     collection = db.xyz

    # 設定要連線到Kafka集群的相關設定, 產生一個Kafka的Consumer的實例
    consumer = KafkaConsumer(
        # 指定Kafka集群伺服器
        bootstrap_servers=["kafka:9092"],
        # ConsumerGroup的名稱, 可以不指定
        #group_id="cg_001",
        # 指定msgKey的反序列化器, 若Key為None, 無法反序列化
        # key_deserializer=bytes.decode,
        # 指定msgValue的反序列化器
        #value_deserializer=bytes.decode,
        value_deserializer=lambda m: json.loads(m.decode('ascii')),
        # 是否從這個ConsumerGroup尚未讀取的partition / offset開始讀
        auto_offset_reset="earliest",
    )
   
    # 讓Consumer向Kafka集群訂閱指定的topic
    consumer.subscribe(topics="status")
    
    es = Elasticsearch('http://elasticsearch:9200')
    
    
    # 持續的拉取Kafka有進來的訊息
    try:
        print("Now listening for incoming messages ...")
        # 持續監控是否有新的record進來
        for record in consumer:
            topic = record.topic
            partition = record.partition
            offset = record.offset
            timestamp = record.timestamp
            # 取出msgKey與msgValue
            msgKey = record.key
            msgValue = record.value
            # 秀出metadata與msgKey & msgValue訊息
            print("topic=%s, partition=%s, offset=%s : (key=%s, value=%s)" % (record.topic, record.partition, 
                                                                              record.offset, record.key, record.value))
            j = {"ID": msgValue["ID"], "DateTime": msgValue["DateTime"], 
                 "status": msgValue["status"], "music": msgValue["music"], "status": msgValue["status"]}
            print("json=",  j)
            
#             # 將資料存入 mongodb
#             # 存入單筆
#             result = collection.insert_one(j)
#             # 存入多筆
#             # result = collection.insert_many()
#             print(result)


            res = es.index(index="status", doc_type='tweet', id=datetime.datetime.now(), body=j)
            print(res['result'])

    except:
        # 錯誤處理
        e_type, e_value, e_traceback = sys.exc_info()
        print("type ==> %s" % (e_type))
        print("value ==> %s" % (e_value))
        print("traceback ==> file name: %s" % (e_traceback.tb_frame.f_code.co_filename))
        print("traceback ==> line no: %s" % (e_traceback.tb_lineno))
        print("traceback ==> function name: %s" % (e_traceback.tb_frame.f_code.co_name))
    finally:
        consumer.close()
# Out:
# Now listening for incoming messages ...
# topic=status, partition=0, offset=0 : (key=None, value={'status': 'run', 'music': '03.mp3', 'DateTime': '2019-10-23 12:03:53', 'ID': 'yoyo'})
# json= {'ID': 'yoyo', 'DateTime': '2019-10-23 12:03:53', 'status': 'run', 'music': '03.mp3'}
# created
# topic=status, partition=0, offset=1 : (key=None, value={'status': 'run', 'music': '03.mp3', 'DateTime': '2019-10-23 12:04:04', 'ID': 'yoyo'})
# json= {'ID': 'yoyo', 'DateTime': '2019-10-23 12:04:04', 'status': 'run', 'music': '03.mp3'}
# created
# topic=status, partition=0, offset=2 : (key=None, value={'status': 'run', 'music': '03.mp3', 'DateTime': '2019-10-23 12:04:14', 'ID': 'yoyo'})
# json= {'ID': 'yoyo', 'DateTime': '2019-10-23 12:04:14', 'status': 'run', 'music': '03.mp3'}
# created
# topic=status, partition=0, offset=3 : (key=None, value={'status': 'run', 'music': '03.mp3', 'DateTime': '2019-10-23 12:04:24', 'ID': 'yoyo'})
# json= {'ID': 'yoyo', 'DateTime': '2019-10-23 12:04:24', 'status': 'run', 'music': '03.mp3'}
# created
# topic=status, partition=0, offset=4 : (key=None, value={'status': 'run', 'music': '03.mp3', 'DateTime': '2019-10-23 12:04:34', 'ID': 'yoyo'})
# json= {'ID': 'yoyo', 'DateTime': '2019-10-23 12:04:34', 'status': 'run', 'music': '03.mp3'}
# created
# topic=status, partition=0, offset=5 : (key=None, value={'status': 'run', 'music': '03.mp3', 'DateTime': '2019-10-23 12:04:44', 'ID': 'yoyo'})
# json= {'ID': 'yoyo', 'DateTime': '2019-10-23 12:04:44', 'status': 'run', 'music': '03.mp3'}
# created
# topic=status, partition=0, offset=6 : (key=None, value={'status': 'run', 'music': '03.mp3', 'DateTime': '2019-10-23 12:04:54', 'ID': 'yoyo'})
# json= {'ID': 'yoyo', 'DateTime': '2019-10-23 12:04:54', 'status': 'run', 'music': '03.mp3'}
# created
# topic=status, partition=0, offset=7 : (key=None, value={'status': 'run', 'music': '03.mp3', 'DateTime': '2019-10-23 12:05:04', 'ID': 'yoyo'})
# json= {'ID': 'yoyo', 'DateTime': '2019-10-23 12:05:04', 'status': 'run', 'music': '03.mp3'}
# created
# topic=status, partition=0, offset=8 : (key=None, value={'status': 'run', 'music': '03.mp3', 'DateTime': '2019-10-23 12:05:15', 'ID': 'yoyo'})
# json= {'ID': 'yoyo', 'DateTime': '2019-10-23 12:05:15', 'status': 'run', 'music': '03.mp3'}
# created
# topic=status, partition=0, offset=9 : (key=None, value={'status': 'run', 'music': '03.mp3', 'DateTime': '2019-10-23 12:05:25', 'ID': 'yoyo'})
# json= {'ID': 'yoyo', 'DateTime': '2019-10-23 12:05:25', 'status': 'run', 'music': '03.mp3'}
# created
# topic=status, partition=0, offset=10 : (key=None, value={'status': 'run', 'music': '03.mp3', 'DateTime': '2019-10-23 12:05:35', 'ID': 'yoyo'})
# json= {'ID': 'yoyo', 'DateTime': '2019-10-23 12:05:35', 'status': 'run', 'music': '03.mp3'}
# created
# topic=status, partition=0, offset=11 : (key=None, value={'status': 'run', 'music': '03.mp3', 'DateTime': '2019-10-23 12:05:45', 'ID': 'yoyo'})
# json= {'ID': 'yoyo', 'DateTime': '2019-10-23 12:05:45', 'status': 'run', 'music': '03.mp3'}
# created
# topic=status, partition=0, offset=12 : (key=None, value={'status': 'run', 'music': '03.mp3', 'DateTime': '2019-10-23 12:05:55', 'ID': 'yoyo'})
# json= {'ID': 'yoyo', 'DateTime': '2019-10-23 12:05:55', 'status': 'run', 'music': '03.mp3'}
# created
# topic=status, partition=0, offset=13 : (key=None, value={'status': 'run', 'music': '03.mp3', 'DateTime': '2019-10-23 12:06:05', 'ID': 'yoyo'})
# json= {'ID': 'yoyo', 'DateTime': '2019-10-23 12:06:05', 'status': 'run', 'music': '03.mp3'}
# created
# topic=status, partition=0, offset=14 : (key=None, value={'status': 'run', 'music': '03.mp3', 'DateTime': '2019-10-23 12:06:15', 'ID': 'yoyo'})
# json= {'ID': 'yoyo', 'DateTime': '2019-10-23 12:06:15', 'status': 'run', 'music': '03.mp3'}
# created
# topic=status, partition=0, offset=15 : (key=None, value={'status': 'run', 'music': '03.mp3', 'DateTime': '2019-10-23 12:06:25', 'ID': 'yoyo'})
# json= {'ID': 'yoyo', 'DateTime': '2019-10-23 12:06:25', 'status': 'run', 'music': '03.mp3'}
# created
# topic=status, partition=0, offset=16 : (key=None, value={'status': 'run', 'music': '03.mp3', 'DateTime': '2019-10-23 12:06:35', 'ID': 'yoyo'})
# json= {'ID': 'yoyo', 'DateTime': '2019-10-23 12:06:35', 'status': 'run', 'music': '03.mp3'}
# created
# topic=status, partition=0, offset=17 : (key=None, value={'status': 'run', 'music': '03.mp3', 'DateTime': '2019-10-23 12:06:45', 'ID': 'yoyo'})
# json= {'ID': 'yoyo', 'DateTime': '2019-10-23 12:06:45', 'status': 'run', 'music': '03.mp3'}
# created
# topic=status, partition=0, offset=18 : (key=None, value={'status': 'run', 'music': '03.mp3', 'DateTime': '2019-10-23 12:06:56', 'ID': 'yoyo'})
# json= {'ID': 'yoyo', 'DateTime': '2019-10-23 12